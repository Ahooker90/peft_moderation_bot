# %%
# !pip install -U "transformers>=4.39.0"
# !pip install peft bitsandbytes
# !pip install -U "trl>=0.8.3"
# Out:
# Requirement already satisfied: transformers>=4.39.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (4.39.3)
# Collecting transformers>=4.39.0
#   Downloading transformers-4.40.1-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 1.4 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Requirement already satisfied: filelock in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (2023.12.25)
# Requirement already satisfied: requests in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.39.0)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.39.0) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.39.0) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.39.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.39.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.39.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.39.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.39.0) (2024.2.2)
# Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 30.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 31.7 MB/s eta 0:00:00m eta 0:00:010:01m
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# Successfully installed tokenizers-0.19.1 transformers-4.40.1
# Collecting peft
#   Using cached peft-0.10.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: bitsandbytes in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (0.42.0)
# Requirement already satisfied: numpy>=1.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (23.2)
# Requirement already satisfied: psutil in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (5.9.0)
# Requirement already satisfied: pyyaml in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (2.2.2)
# Requirement already satisfied: transformers in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (4.40.1)
# Requirement already satisfied: tqdm in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (4.66.2)
# Requirement already satisfied: accelerate>=0.21.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (0.29.2)
# Requirement already satisfied: safetensors in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (0.4.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from peft) (0.22.2)
# Requirement already satisfied: scipy in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from bitsandbytes) (1.13.0)
# Requirement already satisfied: filelock in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft) (2024.3.1)
# Requirement already satisfied: requests in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft) (4.9.0)
# Requirement already satisfied: sympy in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1)
# Requirement already satisfied: jinja2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers->peft) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Using cached peft-0.10.0-py3-none-any.whl (199 kB)
# Installing collected packages: peft
# Successfully installed peft-0.10.0
# Collecting trl>=0.8.3
#   Downloading trl-0.8.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.4.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from trl>=0.8.3) (2.2.2)
# Requirement already satisfied: transformers>=4.31.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from trl>=0.8.3) (4.40.1)
# Requirement already satisfied: numpy>=1.18.2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from trl>=0.8.3) (1.26.4)
# Requirement already satisfied: accelerate in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from trl>=0.8.3) (0.29.2)
# Collecting datasets (from trl>=0.8.3)
#   Downloading datasets-2.19.0-py3-none-any.whl.metadata (19 kB)
# Collecting tyro>=0.5.11 (from trl>=0.8.3)
#   Downloading tyro-0.8.3-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: filelock in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.4.0->trl>=0.8.3) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.4.0->trl>=0.8.3) (4.9.0)
# Requirement already satisfied: sympy in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.4.0->trl>=0.8.3) (1.12)
# Requirement already satisfied: networkx in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.4.0->trl>=0.8.3) (3.1)
# Requirement already satisfied: jinja2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.4.0->trl>=0.8.3) (3.1.3)
# Requirement already satisfied: fsspec in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from torch>=1.4.0->trl>=0.8.3) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (0.22.2)
# Requirement already satisfied: packaging>=20.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (2023.12.25)
# Requirement already satisfied: requests in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from transformers>=4.31.0->trl>=0.8.3) (4.66.2)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl>=0.8.3)
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: rich>=11.1.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from tyro>=0.5.11->trl>=0.8.3) (13.3.5)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl>=0.8.3)
#   Using cached shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: psutil in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from accelerate->trl>=0.8.3) (5.9.0)
# Collecting pyarrow>=12.0.0 (from datasets->trl>=0.8.3)
#   Downloading pyarrow-16.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets->trl>=0.8.3)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from datasets->trl>=0.8.3) (0.3.7)
# Collecting pandas (from datasets->trl>=0.8.3)
#   Using cached pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting xxhash (from datasets->trl>=0.8.3)
#   Using cached xxhash-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->trl>=0.8.3)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting aiohttp (from datasets->trl>=0.8.3)
#   Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->trl>=0.8.3)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from aiohttp->datasets->trl>=0.8.3) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->trl>=0.8.3)
#   Using cached frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->trl>=0.8.3)
#   Using cached multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->trl>=0.8.3)
#   Using cached yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl>=0.8.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl>=0.8.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl>=0.8.3) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl>=0.8.3) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl>=0.8.3) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl>=0.8.3) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from jinja2->torch>=1.4.0->trl>=0.8.3) (2.1.3)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->trl>=0.8.3)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from pandas->datasets->trl>=0.8.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from pandas->datasets->trl>=0.8.3) (2023.3.post1)
# Collecting tzdata>=2022.7 (from pandas->datasets->trl>=0.8.3)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from sympy->torch>=1.4.0->trl>=0.8.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl>=0.8.3) (0.1.0)
# Requirement already satisfied: six>=1.5 in /home/ree398/.conda/envs/viz/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl>=0.8.3) (1.16.0)
# Downloading trl-0.8.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 2.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading tyro-0.8.3-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 8.5 MB/s eta 0:00:00
# Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.2 MB/s eta 0:00:006 MB/s eta 0:00:01
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.1 MB/s eta 0:00:0031m24.1 MB/s eta 0:00:01
# Downloading pyarrow-16.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 52.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached shtab-1.7.1-py3-none-any.whl (14 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached xxhash-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
# Using cached multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (328 kB)
# Installing collected packages: xxhash, tzdata, shtab, pyarrow-hotfix, pyarrow, multidict, frozenlist, docstring-parser, dill, yarl, pandas, multiprocess, aiosignal, tyro, aiohttp, datasets, trl
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 datasets-2.19.0 dill-0.3.8 docstring-parser-0.16 frozenlist-1.4.1 multidict-6.0.5 multiprocess-0.70.16 pandas-2.2.2 pyarrow-16.0.0 pyarrow-hotfix-0.6 shtab-1.7.1 trl-0.8.6 tyro-0.8.3 tzdata-2024.1 xxhash-3.4.1 yarl-1.9.4

# %%
import torch
from transformers import AutoTokenizer, AutoProcessor, TrainingArguments, LlavaForConditionalGeneration, BitsAndBytesConfig
from trl import SFTTrainer
from peft import LoraConfig

# %%
model_id = "llava-hf/llava-1.5-7b-hf"
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
)
model = LlavaForConditionalGeneration.from_pretrained(model_id,
                                                      quantization_config=quantization_config,
                                                      torch_dtype=torch.float16)
# Out:
# config.json:   0%|          | 0.00/950 [00:00<?, ?B/s]
# /home/ree398/.conda/envs/viz/lib/python3.11/site-packages/transformers/models/llava/configuration_llava.py:103: FutureWarning: The `vocab_size` argument is deprecated and will be removed in v4.42, since it can be inferred from the `text_config`. Passing this argument has no effect
#   warnings.warn(
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/70.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
processor = AutoProcessor.from_pretrained(model_id)
processor.tokenizer = tokenizer
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preprocessor_config.json:   0%|          | 0.00/557 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import json
 
# Opening JSON file
train_file = open('train_data.json')
test_file = open('test_data.json')
# returns JSON object as 
# a dictionary
train_data = json.load(train_file)
test_data = json.load(test_file)
print(len(train_data))
print(len(test_data))
# Out:
# 257
# 29

# %%
train_data
# Out:
# [{'id': 'Consensual_73',
#   'image': '/unity_images/data/C_0/Consensual_73.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_16',
#   'image': '/unity_images/data/NC_0/Nonconsensual_16.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_45',
#   'image': '/unity_images/data/NC_0/Nonconsensual_45.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_53',
#   'image': '/unity_images/data/C_0/Consensual_53.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_17',
#   'image': '/unity_images/data/C_0/Consensual_17.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_6',
#   'image': '/unity_images/data/NC_0/Nonconsensual_6.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_61',
#   'image': '/unity_images/data/C_0/Consensual_61.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_8',
#   'image': '/unity_images/data/NC_0/Nonconsensual_8.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_59',
#   'image': '/unity_images/data/NC_0/Nonconsensual_59.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_75',
#   'image': '/unity_images/data/C_0/Consensual_75.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_69',
#   'image': '/unity_images/data/C_0/Consensual_69.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_1',
#   'image': '/unity_images/data/NC_0/Nonconsensual_1.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_2',
#   'image': '/unity_images/data/C_0/Nonconsensual_2.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_58',
#   'image': '/unity_images/data/NC_0/Nonconsensual_58.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_16',
#   'image': '/unity_images/data/C_0/Consensual_16.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_27',
#   'image': '/unity_images/data/NC_0/Nonconsensual_27.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_12',
#   'image': '/unity_images/data/NC_0/Nonconsensual_12.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_18',
#   'image': '/unity_images/data/NC_0/Nonconsensual_18.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_12',
#   'image': '/unity_images/data/C_0/Consensual_12.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_53',
#   'image': '/unity_images/data/C_0/Consensual_53.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_13',
#   'image': '/unity_images/data/NC_0/Nonconsensual_13.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_27',
#   'image': '/unity_images/data/C_0/Consensual_27.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_54',
#   'image': '/unity_images/data/C_0/Consensual_54.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_37',
#   'image': '/unity_images/data/C_0/Consensual_37.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_26',
#   'image': '/unity_images/data/NC_0/Nonconsensual_26.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual
png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_57',
#   'image': '/unity_images/data/C_0/Consensual_57.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_42',
#   'image': '/unity_images/data/NC_0/Nonconsensual_42.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_21',
#   'image': '/unity_images/data/NC_0/Nonconsensual_21.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_54',
#   'image': '/unity_images/data/NC_0/Nonconsensual_54.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_36',
#   'image': '/unity_images/data/NC_0/Nonconsensual_36.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_19',
#   'image': '/unity_images/data/NC_0/Nonconsensual_19.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_48',
#   'image': '/unity_images/data/NC_0/Nonconsensual_48.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_47',
#   'image': '/unity_images/data/C_0/Consensual_47.png',
#   'conversations': [{'from': 'human',
# ...
#   'image': '/unity_images/data/C_0/Consensual_74.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_3',
#   'image': '/unity_images/data/C_0/Consensual_3.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_71',
#   'image': '/unity_images/data/C_0/Consensual_71.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_43',
#   'image': '/unity_images/data/NC_0/Nonconsensual_43.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_51',
#   'image': '/unity_images/data/NC_0/Nonconsensual_51.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_33',
#   'image': '/unity_images/data/NC_0/Nonconsensual_33.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_65',
#   'image': '/unity_images/data/C_0/Consensual_65.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_63',
#   'image': '/unity_images/data/C_0/Consensual_63.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_9',
#   'image': '/unity_images/data/NC_0/Nonconsensual_9.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_35',
#   'image': '/unity_images/data/C_0/Consensual_35.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_5',
#   'image': '/unity_images/data/NC_0/Nonconsensual_5.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_4',
#   'image': '/unity_images/data/NC_0/Nonconsensual_4.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_38',
#   'image': '/unity_images/data/NC_0/Nonconsensual_38.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_56',
#   'image': '/unity_images/data/NC_0/Nonconsensual_56.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_0',
#   'image': '/unity_images/data/C_0/Consensual_0.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_14',
#   'image': '/unity_images/data/C_0/Consensual_14.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_73',
#   'image': '/unity_images/data/C_0/Consensual_73.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_49',
#   'image': '/unity_images/data/C_0/Consensual_49.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_7',
#   'image': '/unity_images/data/C_0/Consensual_7.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_15',
#   'image': '/unity_images/data/C_0/Consensual_15.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_32',
#   'image': '/unity_images/data/NC_0/Nonconsensual_32.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_46',
#   'image': '/unity_images/data/NC_0/Nonconsensual_46.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_15',
#   'image': '/unity_images/data/C_0/Consensual_15.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_68',
#   'image': '/unity_images/data/C_0/Consensual_68.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_10',
#   'image': '/unity_images/data/NC_0/Nonconsensual_10.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_28',
#   'image': '/unity_images/data/NC_0/Nonconsensual_28.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_0',
#   'image': '/unity_images/data/C_0/Nonconsensual_0.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_19',
#   'image': '/unity_images/data/NC_0/Nonconsensual_19.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_38',
#   'image': '/unity_images/data/C_0/Consensual_38.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_21',
#   'image': '/unity_images/data/C_0/Consensual_21.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_35',
#   'image': '/unity_images/data/NC_0/Nonconsensual_35.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_64',
#   'image': '/unity_images/data/C_0/Consensual_64.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_47',
#   'image': '/unity_images/data/NC_0/Nonconsensual_47.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_14',
#   'image': '/unity_images/data/NC_0/Nonconsensual_14.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_45',
#   'image': '/unity_images/data/C_0/Consensual_45.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_8',
#   'image': '/unity_images/data/C_0/Consensual_8.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_21',
#   'image': '/unity_images/data/NC_0/Nonconsensual_21.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_43',
#   'image': '/unity_images/data/C_0/Consensual_43.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_30',
#   'image': '/unity_images/data/C_0/Consensual_30.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_56',
#   'image': '/unity_images/data/NC_0/Nonconsensual_56.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_52',
#   'image': '/unity_images/data/C_0/Consensual_52.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_47',
#   'image': '/unity_images/data/C_0/Consensual_47.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_9',
#   'image': '/unity_images/data/C_0/Consensual_9.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_50',
#   'image': '/unity_images/data/C_0/Consensual_50.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_55',
#   'image': '/unity_images/data/NC_0/Nonconsensual_55.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_37',
#   'image': '/unity_images/data/NC_0/Nonconsensual_37.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_72',
#   'image': '/unity_images/data/C_0/Consensual_72.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_2',
#   'image': '/unity_images/data/C_0/Consensual_2.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_1',
#   'image': '/unity_images/data/C_0/Consensual_1.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_48',
#   'image': '/unity_images/data/NC_0/Nonconsensual_48.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_60',
#   'image': '/unity_images/data/NC_0/Nonconsensual_60.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_13',
#   'image': '/unity_images/data/C_0/Consensual_13.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_60',
#   'image': '/unity_images/data/NC_0/Nonconsensual_60.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Nonconsensual_30',
#   'image': '/unity_images/data/NC_0/Nonconsensual_30.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_76',
#   'image': '/unity_images/data/C_0/Consensual_76.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_2',
#   'image': '/unity_images/data/NC_0/Nonconsensual_2.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_4',
#   'image': '/unity_images/data/C_0/Consensual_4.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_57',
#   'image': '/unity_images/data/NC_0/Nonconsensual_57.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_12',
#   'image': '/unity_images/data/C_0/Consensual_12.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Nonconsensual_11',
#   'image': '/unity_images/data/NC_0/Nonconsensual_11.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'Consensual_28',
#   'image': '/unity_images/data/C_0/Consensual_28.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]},
#  {'id': 'Consensual_68',
#   'image': '/unity_images/data/C_0/Consensual_68.png',
#   'conversations': [{'from': 'human',
#     'value': '\nAre intimate areas being touching on a character? Only answer yes or no. Answer:'},
#    {'from': 'gpt', 'value': 'No'}]}]

# %%
training_args = TrainingArguments(
    output_dir="out_dir",
    report_to="tensorboard",
    learning_rate=1.4e-5,
    per_device_train_batch_size=8,
    gradient_accumulation_steps=1,
    logging_steps=5,
    num_train_epochs=1,
    push_to_hub=False,
    gradient_checkpointing=True,
    remove_unused_columns=False,
    fp16=True,
    bf16=False
)

# %%
lora_config = LoraConfig(
    r=64,
    lora_alpha=16,
    target_modules="all-linear"
)

# %%
class LLavaDataCollator:
    def __init__(self, processor):
        self.processor = processor

    def __call__(self, examples):
        texts = []
        images = []
        for example in examples:
            messages = example["messages"]
            text = self.processor.tokenizer.apply_chat_template(
                messages, tokenize=False, add_generation_prompt=False
            )
            texts.append(text)
            images.append(example["images"][0])

        batch = self.processor(texts, images, return_tensors="pt", padding=True)

        labels = batch["input_ids"].clone()
        if self.processor.tokenizer.pad_token_id is not None:
            labels[labels == self.processor.tokenizer.pad_token_id] = -100
        batch["labels"] = labels

        return batch

data_collator = LLavaDataCollator(processor)

# %%
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_data,
    eval_dataset=test_data,
    peft_config=lora_config,
    dataset_text_field='conversations',  # need a dummy field
    tokenizer=tokenizer,
    data_collator=data_collator,
    dataset_kwargs={"skip_prepare_dataset": True},
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 trainer = SFTTrainer(
#       2     model=model,
#       3     args=training_args,
#       4     train_dataset=train_data,
#       5     eval_dataset=test_data,
#       6     peft_config=lora_config,
#       7     dataset_text_field='conversations',  # need a dummy field
#       8     tokenizer=tokenizer,
#       9     data_collator=data_collator,
#      10     dataset_kwargs={"skip_prepare_dataset": True},
#      11 )
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:228, in SFTTrainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics, peft_config, dataset_text_field, packing, formatting_func, max_seq_length, infinite, num_of_sequences, chars_per_token, dataset_num_proc, dataset_batch_size, neftune_noise_alpha, model_init_kwargs, dataset_kwargs, eval_packing)
#     224             output.requires_grad_(True)
#     226         model.get_input_embeddings().register_forward_hook(make_inputs_require_grad)
# --> 228 model = get_peft_model(model, peft_config)
#     229 if (
#     230     args is not None
#     231     and args.bf16
#     232     and getattr(model, "is_loaded_in_4bit", False)
#     233     and not is_sharded_qlora
#     234 ):
#     235     peft_module_casting_to_bf16(model)
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/mapping.py:132, in get_peft_model(model, peft_config, adapter_name, mixed)
#     129     return PeftMixedModel(model, peft_config, adapter_name=adapter_name)
#     131 if peft_config.task_type not in MODEL_TYPE_TO_PEFT_MODEL_MAPPING.keys() and not peft_config.is_prompt_learning:
# --> 132     return PeftModel(model, peft_config, adapter_name=adapter_name)
#     134 if peft_config.is_prompt_learning:
#     135     peft_config = _prepare_prompt_learning_config(peft_config, model_config)
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/peft_model.py:129, in PeftModel.__init__(self, model, peft_config, adapter_name)
#     127     self._peft_config = None
#     128     cls = PEFT_TYPE_TO_MODEL_MAPPING[peft_config.peft_type]
# --> 129     self.base_model = cls(model, {adapter_name: peft_config}, adapter_name)
#     130     self.set_additional_trainable_modules(peft_config, adapter_name)
#     132 if getattr(model, "is_gradient_checkpointing", True):
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/tuners/lora/model.py:136, in LoraModel.__init__(self, model, config, adapter_name)
#     135 def __init__(self, model, config, adapter_name) -> None:
# --> 136     super().__init__(model, config, adapter_name)
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/tuners/tuners_utils.py:148, in BaseTuner.__init__(self, model, peft_config, adapter_name)
#     145         self.peft_config.update(peft_config)
#     147 self.active_adapter = adapter_name
# --> 148 self.inject_adapter(self.model, adapter_name)
#     150 # Copy the peft_config in the injected model.
#     151 self.model.peft_config = self.peft_config
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/tuners/tuners_utils.py:325, in BaseTuner.inject_adapter(self, model, adapter_name)
#     323     is_target_modules_in_base_model = True
#     324     parent, target, target_name = _get_submodules(model, key)
# --> 325     self._create_and_replace(peft_config, adapter_name, target, target_name, parent, current_key=key)
#     327 if not is_target_modules_in_base_model:
#     328     raise ValueError(
#     329         f"Target modules {peft_config.target_modules} not found in the base model. "
#     330         f"Please check the target modules and try again."
#     331     )
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/tuners/lora/model.py:220, in LoraModel._create_and_replace(self, lora_config, adapter_name, target, target_name, parent, current_key)
#     210     target.update_layer(
#     211         adapter_name,
#     212         r,
#    (...)
#     217         use_dora=lora_config.use_dora,
#     218     )
#     219 else:
# --> 220     new_module = self._create_new_module(lora_config, adapter_name, target, **kwargs)
#     221     if adapter_name != self.active_adapter:
#     222         # adding an additional adapter: it is not automatically trainable
#     223         new_module.requires_grad_(False)
#
# File ~/.conda/envs/viz/lib/python3.11/site-packages/peft/tuners/lora/model.py:301, in LoraModel._create_new_module(lora_config, adapter_name, target, **kwargs)
#     297         break
#     299 if new_module is None:
#     300     # no module could be matched
# --> 301     raise ValueError(
#     302         f"Target module {target} is not supported. Currently, only the following modules are supported: "
#     303         "`torch.nn.Linear`, `torch.nn.Embedding`, `torch.nn.Conv2d`, `transformers.pytorch_utils.Conv1D`."
#     304     )
#     306 return new_module
#
# ValueError: Target module Identity() is not supported. Currently, only the following modules are supported: `torch.nn.Linear`, `torch.nn.Embedding`, `torch.nn.Conv2d`, `transformers.pytorch_utils.Conv1D`.
